# %%
import numpy as np
import pandas as pd

# %%
# import sys
# !{sys.executable} -m pip install spotipy

# %%
from top_artists import results
df = pd.DataFrame.from_records(results)

# %%
artists_df = pd.DataFrame.from_records(df["items"])

# %%
artists_df
# Out:
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/artist/0...
# 1   {'spotify': 'https://open.spotify.com/artist/3...
# 2   {'spotify': 'https://open.spotify.com/artist/1...
# 3   {'spotify': 'https://open.spotify.com/artist/6...
# 4   {'spotify': 'https://open.spotify.com/artist/4...
# 5   {'spotify': 'https://open.spotify.com/artist/3...
# 6   {'spotify': 'https://open.spotify.com/artist/4...
# 7   {'spotify': 'https://open.spotify.com/artist/2...
# 8   {'spotify': 'https://open.spotify.com/artist/7...
# 9   {'spotify': 'https://open.spotify.com/artist/7...
# 10  {'spotify': 'https://open.spotify.com/artist/4...
# 11  {'spotify': 'https://open.spotify.com/artist/1...
# 12  {'spotify': 'https://open.spotify.com/artist/0...
# 13  {'spotify': 'https://open.spotify.com/artist/6...
# 14  {'spotify': 'https://open.spotify.com/artist/6...
# 15  {'spotify': 'https://open.spotify.com/artist/0...
# ...
